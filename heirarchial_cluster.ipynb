# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %%
file_path_user_cleaned = r'C:\Users\Anush\Downloads\archive\users_cleaned.csv'
df_users_cleaned = pd.read_csv(file_path_user_cleaned)

df_users_cleaned
# Out:
#               username  user_id  user_watching  user_completed  user_onhold  \
# 0             karthiga  2255153              3              49            1
# 1            Damonashu    37326             45             195           27
# 2                bskai   228342             25             414            2
# 3       terune_uzumaki   327311              5               5            0
# 4                Bas_G  5015094             35             114            6
# ...                ...      ...            ...             ...          ...
# 108706          isoann   797785             14             213           11
# 108707        bumcakee  1396285             13             116            5
# 108708       Scarlet95  2478991              6             103           10
# 108709        Torasori  3975907             22             239            0
# 108710          HMicca  1289601             11              73            2
#
# ...

# %%
file_path_anime_cleaned = r'C:\Users\Anush\Downloads\archive\anime_cleaned.csv'

df_anime_cleaned = pd.read_csv(file_path_anime_cleaned)

df_anime_cleaned
# Out:
#       anime_id                                              title  \
# 0        11013                                      Inu x Boku SS
# 1         2104                                   Seto no Hanayome
# 2         5262                                 Shugo Chara!! Doki
# 3          721                                      Princess Tutu
# 4        12365                                Bakuman. 3rd Season
# ...        ...                                                ...
# 6663     37405                            Dokidoki Little Ooyasan
# 6664     37886                        Wo Shi Jiang Xiaobai (2018)
# 6665     37255              Genki Genki Non-tan: Obake Mura Meiro
# 6666     35229                                Mr. Men Little Miss
# 6667     36315  Mushi Mushi Mura no Nakama-tachi: Minna Ii Tok...
#
#                   title_english                      title_japanese  \
# 0     Inu X Boku Secret Service                              妖狐×僕SS
# ...
